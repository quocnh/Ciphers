# %%
import pandas as pd
import numpy as np
import math
import string
from collections import Counter
from google.colab import files
from numpy import mean
from numpy import std
from pandas import read_csv
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso, LinearRegression, Ridge
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3b3a802c-b849-4370-8626-75d7bc645ea4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b3a802c-b849-4370-8626-75d7bc645ea4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# read input file
df = pd.read_csv("input.csv")
df
# Out:
#      plain_text cipher_text  cipher_class
# 0     meanwhile   NFBOXIJMF             0
# 1     tradition   USBEJUJPO             0
# 2     following   GPMMPXJOH             0
# 3     ftpuntedu   GUQVOUFEV             0
# 4     testimony   UFTUJNPOZ             0
# ...         ...         ...           ...
# 6106  recipient   VBEQIQRTX             2
# 6107  middlesex   QFFLEMFKB             2
# 6108  regularly   VBICEIERC             2
# 6109  offerings   SCHMKQAMW             2
# 6110  classical   GICALQPGP             2
#
# [6111 rows x 3 columns]

# %% [markdown]
# ### Features engineering

# %%
# currently there are only 2 features, add more to increase the learning performance

# how to add frequece letter as dict features?

# Index of coincidence (IC)

def get_letter_counts(text):
    text_upper = text.upper()
    letter_counts = {}
    for index, letter in enumerate(string.ascii_uppercase):
        letter_counts[letter] = text_upper.count(letter)
    return letter_counts
def get_letter_frequencies(text):
    letter_counts = get_letter_counts(text)
    frequencies = {letter: count/len(text) for letter, count in letter_counts.items()}
    return frequencies
def get_ic(letter_counts):
    numerator = sum([letter_counts[l]*(letter_counts[l]-1) for l in string.ascii_uppercase])
    text_size = sum(occurrences for occurrences in letter_counts.values())
    denominator = text_size*(text_size-1)
    return numerator/denominator


# Number of unique characters (NUC)
def get_nuc(str):
    # Stores all frequencies
    freq = Counter(str)
    # Return the size of the freq dictionary
    return len(freq)

# %%
cipher_text_column = df["cipher_text"].values
cipher_text_column
# Out:
# array(['NFBOXIJMF', 'USBEJUJPO', 'GPMMPXJOH', ..., 'VBICEIERC',
#        'SCHMKQAMW', 'GICALQPGP'], dtype=object)

# %%
# Features engineering functions
def feature_engineering(Dataframe, cipher_text_column):
  df = Dataframe
  ic = []
  nuc = []
  for i in cipher_text_column:
    ic.append(get_ic(get_letter_counts(i)))
    nuc.append(get_nuc(i))
  # add 2 features into df
  df["ic"] = ic
  df["nuc"] = nuc
  
  return df

# %%
df = feature_engineering(df,cipher_text_column)

# %%
df
# Out:
#      plain_text cipher_text  cipher_class        ic  nuc
# 0     meanwhile   NFBOXIJMF             0  0.027778    8
# 1     tradition   USBEJUJPO             0  0.055556    7
# 2     following   GPMMPXJOH             0  0.055556    7
# 3     ftpuntedu   GUQVOUFEV             0  0.055556    7
# 4     testimony   UFTUJNPOZ             0  0.027778    8
# ...         ...         ...           ...       ...  ...
# 6106  recipient   VBEQIQRTX             2  0.027778    8
# 6107  middlesex   QFFLEMFKB             2  0.083333    7
# 6108  regularly   VBICEIERC             2  0.083333    6
# 6109  offerings   SCHMKQAMW             2  0.027778    8
# 6110  classical   GICALQPGP             2  0.055556    7
#
# [6111 rows x 5 columns]

# %%
X = df.loc[:, ['ic', 'nuc']]
# X = df.loc[:, ['nuc']]
y = df["cipher_class"]
print(X.shape)
print(y.shape)
# Out:
# (6111, 2)
# (6111,)

# %%
Counter(y)
# Out:
# Counter({0: 3395, 1: 1358, 2: 1358})

# %%
X[0:5]
# Out:
#          ic  nuc
# 0  0.027778    8
# 1  0.055556    7
# 2  0.055556    7
# 3  0.055556    7
# 4  0.027778    8

# %%
# without scaler
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, stratify = y, shuffle=True)

# %%
model_LR = LogisticRegression()
model_LR.fit(X_train, y_train)
y_hat_LR = model_LR.predict(X_test)
accuracy_score(y_test, y_hat_LR)
# Out:
# 0.6181520850367948

# %%
# without scaler
# intepret with/without Z standardization
scaler= StandardScaler()
X =scaler.fit_transform(X,y) 
X[0:5]
# Out:
# array([[-0.51896888,  0.29732841],
#        [ 0.31949845, -0.64070665],
#        [ 0.31949845, -0.64070665],
#        [ 0.31949845, -0.64070665],
#        [-0.51896888,  0.29732841]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, stratify = y, shuffle=True)

# %%
model_LR = LogisticRegression()
model_LR.fit(X_train, y_train)
y_hat_LR = model_LR.predict(X_test)
accuracy_score(y_test, y_hat_LR)
# Out:
# 0.7432542927228127

# %%
# Use decision tree
model_DTC = DecisionTreeClassifier(max_depth=40).fit(X_train, y_train)
y_hat_DTC = model_DTC.predict(X_test)
y_hat_DTC
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy_score(y_test,y_hat_DTC)
# interpret why DT is better than Logistic model
# Out:
# 0.7735077677841373

# %% [markdown]
# ### improve imbalance dataset with sampling technique, try all and interpret why we chose that

# %% [markdown]
# ### ensemble method
# Decision Tree is not stable, when the data changes slightly causing the tree structure changes drastically. But the prediction od DT is not high due to the simplicity of the model.

# %% [markdown]
# ### Test with unseen dataset

# %%
DrShah = files.upload()
# Out:
#      <input type="file" id="files-972c04ec-7f6d-495d-bf8e-1dfc5f27ac72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-972c04ec-7f6d-495d-bf8e-1dfc5f27ac72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1 = pd.read_csv("input.csv")

# %%
df1

# %%
# Note: please replace your coressponseding "cipher_text" name.
df1 = feature_engineering(df1,df1["cipher_text"])
df1

# %%
X_test1 = df1.loc[:, ['ic', 'nuc']]
X_test1[0:5]

# %%
X_test1 = X_test1.to_numpy()

# %%
type(X_test1)

# %%
len(X_test1)

# %%
# shuffle X_test1
shuffle_index = np.random.permutation(len(X_test1))
X_test1 = X_test1[shuffle_index]
X_test1[0:5]

# %%
y_hat_DTC_1 = model_DTC.predict(X_test1)

# %%
# ask Dr Shah, in test dataset should include y column?
